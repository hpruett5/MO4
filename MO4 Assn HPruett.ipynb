# %%
#11.1 : Task: Create a file called zoo.py. In it, define a function called hours() that prints the string 'Open 9-5 daily'. 
#Then, use the interactive interpreter to import the zoo module and call its hours() function.

# Hannah Pruett
#04-10-2025
# 11.1 Part 2 Task : 11.1 Use the interactive interpreter to import the zoo module and call its hours() function.

import zoo
zoo.hours()

# %%
#11.2 : Task: In the interactive interpreter, import the zoo module as menagerie and call its hours() function.
# Hannah Pruett
#04-10-2025
# 11.2 11.2 In the interactive interpreter, import the zoo module as menagerie and call its hours() function.

import zoo as menagerie
menagerie.hours()

# %%
#16.8 : Task: Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in exercise 16.4. 
#As in 16.6, select and print the title column from the book table in alphabetical order.
    #16.4 Use the sqlite3 module to create a SQLite database called books.db and a table called books with these fields: 
    #title (text), author (text), and year (integer)
    #16.6 Select and print the title column from the book table in alphabetical order.
#HPruett Prob 16

#16.1
text = '''author,book
... J R R Tolkien,The Hobbit
... Lynne Truss,"Eats, Shoots, & Leaves"
'''

import csv

with open ('books.csv', 'wt') as outfile:
    outfile.write(text)

#16.2
with open('books.csv', 'rt') as infile:
    books = csv.DictReader(infile)
    for book in books:
        print(book)

16.3
text = '''title,author,year
... The Weirdstone of Brisingamen,Alan Garner,1960
... Perdido Street Station,China Miéville,2000
... Thud!,Terry Pratchett,2005
... The Spellman Files,Lisa Lutz,2007
... Small Gods,Terry Pratchett,1992
... '''

with open('books2.csv', 'wt') as outfile:
    outfile.write(text)

#16.4
import sqlite3
db = sqlite3.connect('books.db')
curs = db.cursor()
curs.execute('''create table book (title text, author text, year int)''')
db.commit()

#16.5
import csv
import sqlite3

ins_str = 'insert into book values(?,?,?)'
with open('books2.csv', 'rt') as infile:
    books = csv.DictReader(infile)
    for book in books:
        curs.execute(ins_str, (book['title'], book['author'], book['year']))

db.commit ()

#16.6
sql = 'select title from book order by title asc'
for row in db.execute(sql):
    print(row)

#16.7
for row in db.execute('select * from book order by year'):
    print(row)

#16.8
import sqlalchemy
conn = sqlalchemy.create_engine('sqlite:///books.db')
sql = sqlalchemy.text('select title from book order by title asc')
with conn.connect() as connection:
    rows = connection.execute(sql)
    for row in rows:
        print(row)
